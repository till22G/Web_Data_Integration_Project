# %%
# importing packages
import pandas as pd
import lxml

pd.__version__
# Out:
# '1.3.4'

# %%
# load goldstandard .csv-file into dataframe
gs_data_path = '../Data/goldstandard_man.csv'
gs = pd.read_csv(gs_data_path, sep=';')

# lower column names
gs.columns = gs.columns.str.lower()
gs= gs.applymap(lambda s:s.lower() if type(s) == str else s)
gs.head(50)
# Out:
#           id                   provenance           scientific_name  \
# 0     es1476        fws-endangeredspecies   acipenser transmontanus
# 1     es1325        fws-endangeredspecies        trichechus manatus
# 2   bio29503  biodiversityusnationalparks         numenius borealis
# 3   bio39412  biodiversityusnationalparks    sclerocactus wrightiae
# 4     es1457        fws-endangeredspecies       lepidochelys kempii
# 5   bio12700  biodiversityusnationalparks       cyprinodon diabolis
# 6   bio24175  biodiversityusnationalparks     leptonycteris nivalis
# 7   bio02004  biodiversityusnationalparks          anaxyrus canorus
# 8   bio16826  biodiversityusnationalparks      etheostoma percnurum
# 9   bio37045  biodiversityusnationalparks            rana draytonii
# 10    es1544        fws-endangeredspecies         myotis grisescens
# 11  bio24625  biodiversityusnationalparks        lilium occidentale
# 12  bio01978  biodiversityusnationalparks           anas wyvilliana
# 13  bio07055  biodiversityusnationalparks   campephilus principalis
# 14  bio04352  biodiversityusnationalparks        astragalus phoenix
# 15  bio18454  biodiversityusnationalparks           gambusia gaigei
# 16  bio12569  biodiversityusnationalparks         cynomys parvidens
# 17  bio16939  biodiversityusnationalparks   eucyclogobius newberryi
# 18  bio13135  biodiversityusnationalparks         deltistes luxatus
# 19  bio21090  biodiversityusnationalparks        hybognathus amarus
# 20  bio23265  biodiversityusnationalparks         lampsilis abrupta
# 21  bio45023  biodiversityusnationalparks       vermivora bachmanii
# 22  bio28124  biodiversityusnationalparks          mustela nigripes
# 23  bio19413  biodiversityusnationalparks            grus americana
# 24  bio36335  biodiversityusnationalparks  pterodroma sandwichensis
# 25  bio02701  biodiversityusnationalparks   aphelocoma coerulescens
# 26  bio25447  biodiversityusnationalparks          loxops coccineus
# 27  bio33630  biodiversityusnationalparks         picoides borealis
# 28  bio31051  biodiversityusnationalparks            palmeria dolei
# 29  bio09194  biodiversityusnationalparks         chasmistes liorus
# 30  bio21763  biodiversityusnationalparks  hypomesus transpacificus
# 31  bio03113  biodiversityusnationalparks        arctomecon humilis
# 32  bio37053  biodiversityusnationalparks             rana pretiosa
# 33  bio10741  biodiversityusnationalparks       coccyzus americanus
# 34  bio19261  biodiversityusnationalparks       gopherus polyphemus
# 35  bio19259  biodiversityusnationalparks        gopherus agassizii
# 36  bio29607  biodiversityusnationalparks           obovaria retusa
# 37  bio34395  biodiversityusnationalparks         pleurobema plenum
# 38  bio34392  biodiversityusnationalparks          pleurobema clava
# 39  bio29617  biodiversityusnationalparks        oceanodroma castro
# 40  bio36090  biodiversityusnationalparks  pseudonestor xanthophrys
# 41  bio08558  biodiversityusnationalparks      centrocercus minimus
# 42  bio05812  biodiversityusnationalparks  brachyramphus marmoratus
# 43    es1509        fws-endangeredspecies      megalagrion nesiotes
# 44    es1185        fws-endangeredspecies     megalagrion pacificum
# 45    es1140        fws-endangeredspecies   megalagrion xanthomelas
# 46    es1179        fws-endangeredspecies    psittirostra psittacea
# 47  bio09158  biodiversityusnationalparks        charadrius melodus
# 48  bio40443  biodiversityusnationalparks       sistrurus catenatus
# 49  bio25449  biodiversityusnationalparks          loxops ochraceus
#
#                                           common_name  label  where_listed  \
# 0   white sturgeon|pacific sturgeon|oregon sturgeo...    NaN           NaN
# 1   west indian manatee|sea cow|north american man...    NaN           NaN
# 2                       eskimo curlew|northern curlew    NaN           NaN
# 3   wright's fishhook cactus|wright's little barre...    NaN           NaN
# 4   kemp's ridley sea turtle|atlantic ridley sea t...    NaN           NaN
# 5                                 devils hole pupfish    NaN           NaN
# 6   mexican long-nosed bat|big long-nosed bat|grea...    NaN           NaN
# 7                                       yosemite toad    NaN           NaN
# 8                                    duskytail darter    NaN           NaN
# 9                          california red-legged frog    NaN           NaN
# 10                                           gray bat    NaN           NaN
# 11                                       western lily    NaN           NaN
# 12                                koloa|hawaiian duck    NaN           NaN
# 13                            ivory-billed woodpecker    NaN           NaN
# 14       ash meadows milkvetch|ash meadows milk-vetch    NaN           NaN
# 15                                  big bend gambusia    NaN           NaN
# 16                                   utah prairie dog    NaN           NaN
# 17                                     tidewater goby    NaN           NaN
# 18                                  lost river sucker    NaN           NaN
# 19                          rio grande silvery minnow    NaN           NaN
# 20                                        pink mucket    NaN           NaN
# 21           bachman's wood warbler|bachman's warbler    NaN           NaN
# 22            black-footed ferret|ferret|black-footed    NaN           NaN
# 23                                     whooping crane    NaN           NaN
# 24  hawaiian petrel|hawaiian dark-rumped petrel|`ua`u    NaN           NaN
# 25      florida scrub jay|scrub jay|florida scrub-jay    NaN           NaN
# 26                                    hawai'i' 'akepa    NaN           NaN
# 27                            red-cockaded woodpecker    NaN           NaN
# 28                     akohekohe|crested honeycreeper    NaN           NaN
# 29                                        june sucker    NaN           NaN
# 30                                        delta smelt    NaN           NaN
# 31  dwarf bear poppy|common bearpoppy|dwarf bearpoppy    NaN           NaN
# 32                   oregon spotted frog|spotted frog    NaN           NaN
# 33  eastern yellow-billed cuckoo|yellow-billed cuc...    NaN           NaN
# 34                                    gopher tortoise    NaN           NaN
# 35  agassiz's desert tortoise|mojave desert tortoi...    NaN           NaN
# 36  ring pink|ring pink mussel|golf stick pearly m...    NaN           NaN
# 37            rough pigtoe|rough pigtoe pearly mussel    NaN           NaN
# 38       clubshell|club naiad|clubshell pearly mussel    NaN           NaN
# 39  band-rumped storm petrel|`ake`ake|band-rumped ...    NaN           NaN
# 40                            maui parrotbill|kiwikiu    NaN           NaN
# 41  gunnison grouse|gunnison sage-grouse|lesser sa...    NaN           NaN
# 42              marbled murrelet|long-billed murrelet    NaN           NaN
# 43                   flying earwig hawaiian damselfly    NaN           NaN
# 44                         pacific hawaiian damselfly    NaN           NaN
# 45                     orangeblack hawaiian damselfly    NaN           NaN
# 46                                  `o`u|honeycreeper    NaN           NaN
# 47                piping plover|eastern piping plover    NaN           NaN
# 48                       massasauga|desert massasauga    NaN           NaN
# 49                                        maui 'akepa    NaN           NaN
#
#     different_from  endemic_to region        region_name  \
# 0              NaN         NaN      1            pacific
# 1              NaN         NaN      4          southeast
# 2              NaN         NaN      5          northeast
# 3              NaN         NaN      6   mountain prairie
# 4              NaN         NaN      2          southwest
# 5              NaN         NaN      8  pacific southwest
# 6              NaN         NaN      2          southwest
# 7              NaN         NaN      8  pacific southwest
# 8              NaN         NaN      4          southeast
# 9              NaN         NaN      8  pacific southwest
# 10             NaN         NaN      3            midwest
# 11             NaN         NaN      8  pacific southwest
# 12             NaN         NaN      1            pacific
# 13             NaN         NaN      4          southeast
# 14             NaN         NaN      8  pacific southwest
# 15             NaN         NaN      2          southwest
# 16             NaN         NaN      6   mountain-prairie
# 17             NaN         NaN      8  pacific southwest
# 18             NaN         NaN      8  pacific southwest
# 19             NaN         NaN      2          southwest
# 20             NaN         NaN      3            midwest
# 21             NaN         NaN      4          southeast
# 22             NaN         NaN      6   mountain-prairie
# 23             NaN         NaN      2          southwest
# 24             NaN         NaN      1            pacific
# 25             NaN         NaN      4          southeast
# 26             NaN         NaN      1            pacific
# 27             NaN         NaN      4          southeast
# 28             NaN         NaN      1            pacific
# 29             NaN         NaN      6   mountain-prairie
# 30             NaN         NaN      8  pacific southwest
# 31             NaN         NaN      6   mountain-prairie
# 32             NaN         NaN      1            pacific
# 33             NaN         NaN      2          southwest
# 34             NaN         NaN      4          southeast
# 35             NaN         NaN      8  pacific southwest
# 36             NaN         NaN      4          southeast
# 37             NaN         NaN      4          southeast
# 38             NaN         NaN      5          northeast
# 39             NaN         NaN      1            pacific
# 40             NaN         NaN      1            pacific
# 41             NaN         NaN      6   mountain-prairie
# 42             NaN         NaN      1            pacific
# 43             NaN         NaN      1            pacific
# 44             NaN         NaN      1            pacific
# 45             NaN         NaN      1            pacific
# 46             NaN         NaN      1            pacific
# 47             NaN         NaN    0|1  northeast|midwest
# 48             NaN         NaN      3            midwest
# 49             NaN         NaN      1            pacific
#
#              listing_status        category               order  \
# 0                endangered            fish    acipenseriformes
# 1                threatened          mammal             sirenia
# 2                endangered            bird     charadriiformes
# 3                endangered  vascular plant      caryophyllales
# 4                endangered         reptile          testudines
# 5                endangered            fish  cyprinodontiformes
# 6                endangered          mammal          chiroptera
# 7                threatened       amphibian               anura
# 8                endangered            fish         perciformes
# 9                threatened       amphibian               anura
# 10               endangered          mammal          chiroptera
# 11               endangered  vascular plant            liliales
# 12               endangered            bird        anseriformes
# 13               endangered            bird          piciformes
# 14               threatened  vascular plant             fabales
# 15               endangered            fish  cyprinodontiformes
# 16               threatened          mammal            rodentia
# 17               endangered            fish         perciformes
# 18               endangered            fish       cypriniformes
# 19               endangered            fish       cypriniformes
# 20               endangered    invertebrate           unionoida
# 21               endangered            bird       passeriformes
# 22               endangered          mammal           carnivora
# 23               endangered            bird          gruiformes
# 24               endangered            bird   procellariiformes
# 25               threatened            bird       passeriformes
# 26               endangered            bird       passeriformes
# 27               endangered            bird          piciformes
# 28               endangered            bird       passeriformes
# 29               endangered            fish       cypriniformes
# 30               threatened            fish        osmeriformes
# 31               endangered  vascular plant        ranunculales
# 32               threatened       amphibian               anura
# 33               threatened            bird        cuculiformes
# 34  under review|threatened         reptile          testudines
# 35               endangered         reptile          testudines
# 36               endangered    invertebrate           unionoida
# 37               endangered    invertebrate           unionoida
# 38               endangered    invertebrate           unionoida
# 39               endangered            bird   procellariiformes
# 40               endangered            bird       passeriformes
# 41               endangered            bird         galliformes
# 42               threatened            bird     charadriiformes
# 43               endangered          insect             odonata
# 44               endangered          insect             odonata
# 45               endangered          insect             odonata
# 46               endangered            bird       passeriformes
# 47               threatened            bird     charadriiformes
# 48      proposed threatened         reptile            squamata
# 49               endangered            bird       passeriformes
#
#               family     state
# 0      acipenseridae       NaN
# 1       trichechidae       NaN
# 2       scolopacidae        me
# 3          cactaceae        ut
# 4        cheloniidae       NaN
# 5    cyprinodontidae     ca|nv
# 6     phyllostomidae  az|tx|nm
# 7          bufonidae        ca
# 8           percidae     nc|tn
# 9            ranidae     ca|nv
# 10  vespertilionidae       NaN
# 11         liliaceae        ca
# 12          anatidae        hi
# 13           picidae     sc|fl
# 14          fabaceae     ca|nv
# 15       poeciliidae       NaN
# 16         sciuridae       NaN
# 17          gobiidae       NaN
# 18      catostomidae       NaN
# 19        cyprinidae       NaN
# 20         unionidae       NaN
# 21         parulidae       NaN
# 22        mustelidae       NaN
# 23           gruidae       NaN
# 24    procellariidae       NaN
# 25          corvidae       NaN
# 26      fringillidae       NaN
# 27           picidae       NaN
# 28      fringillidae       NaN
# 29      catostomidae       NaN
# 30         osmeridae       NaN
# 31      papaveraceae       NaN
# 32           ranidae       NaN
# 33         cuculidae       NaN
# 34      testudinidae       NaN
# 35      testudinidae       NaN
# 36         unionidae       NaN
# 37         unionidae       NaN
# 38         unionidae       NaN
# 39      hydrobatidae       NaN
# 40      fringillidae        hi
# 41       phasianidae       NaN
# 42           alcidae       NaN
# 43    coenagrionidae       NaN
# 44    coenagrionidae       NaN
# 45    coenagrionidae       NaN
# 46      fringillidae       NaN
# 47      charadriidae       NaN
# 48         viperidae       NaN
# 49      fringillidae       NaN

# %%
print(gs.to_xml(index=False, root_name='animals_and_plants', row_name='species'))
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <animals_and_plants>
#   <species>
#     <id>es1476</id>
#     <provenance>fws-endangeredspecies</provenance>
#     <scientific_name>acipenser transmontanus</scientific_name>
#     <common_name>white sturgeon|pacific sturgeon|oregon sturgeon|columbia sturgeon|snake river sturgeon|sacramento sturgeon</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>fish</category>
#     <order>acipenseriformes</order>
#     <family>acipenseridae</family>
#     <state/>
#   </species>
#   <species>
#     <id>es1325</id>
#     <provenance>fws-endangeredspecies</provenance>
#     <scientific_name>trichechus manatus</scientific_name>
#     <common_name>west indian manatee|sea cow|north american manatee</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>threatened</listing_status>
#     <category>mammal</category>
#     <order>sirenia</order>
#     <family>trichechidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio29503</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>numenius borealis</scientific_name>
#     <common_name>eskimo curlew|northern curlew</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>5</region>
#     <region_name>northeast</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>charadriiformes</order>
#     <family>scolopacidae</family>
#     <state>me</state>
#   </species>
#   <species>
#     <id>bio39412</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>sclerocactus wrightiae</scientific_name>
#     <common_name>wright's fishhook cactus|wright's little barrel cactus</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>6</region>
#     <region_name>mountain prairie</region_name>
#     <listing_status>endangered</listing_status>
#     <category>vascular plant</category>
#     <order>caryophyllales</order>
#     <family>cactaceae</family>
#     <state>ut</state>
#   </species>
#   <species>
#     <id>es1457</id>
#     <provenance>fws-endangeredspecies</provenance>
#     <scientific_name>lepidochelys kempii</scientific_name>
#     <common_name>kemp's ridley sea turtle|atlantic ridley sea turtle|bastard turtle</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>2</region>
#     <region_name>southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>reptile</category>
#     <order>testudines</order>
#     <family>cheloniidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio12700</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>cyprinodon diabolis</scientific_name>
#     <common_name>devils hole pupfish</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>fish</category>
#     <order>cyprinodontiformes</order>
#     <family>cyprinodontidae</family>
#     <state>ca|nv</state>
#   </species>
#   <species>
#     <id>bio24175</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>leptonycteris nivalis</scientific_name>
#     <common_name>mexican long-nosed bat|big long-nosed bat|greater long-nosed bat</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>2</region>
#     <region_name>southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>mammal</category>
#     <order>chiroptera</order>
#     <family>phyllostomidae</family>
#     <state>az|tx|nm</state>
#   </species>
#   <species>
#     <id>bio02004</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>anaxyrus canorus</scientific_name>
#     <common_name>yosemite toad</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>threatened</listing_status>
#     <category>amphibian</category>
#     <order>anura</order>
#     <family>bufonidae</family>
#     <state>ca</state>
#   </species>
#   <species>
#     <id>bio16826</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>etheostoma percnurum</scientific_name>
#     <common_name>duskytail darter</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>endangered</listing_status>
#     <category>fish</category>
#     <order>perciformes</order>
#     <family>percidae</family>
#     <state>nc|tn</state>
#   </species>
#   <species>
#     <id>bio37045</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>rana draytonii</scientific_name>
#     <common_name>california red-legged frog</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>threatened</listing_status>
#     <category>amphibian</category>
#     <order>anura</order>
#     <family>ranidae</family>
#     <state>ca|nv</state>
#   </species>
#   <species>
#     <id>es1544</id>
#     <provenance>fws-endangeredspecies</provenance>
#     <scientific_name>myotis grisescens</scientific_name>
#     <common_name>gray bat</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>3</region>
#     <region_name>midwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>mammal</category>
#     <order>chiroptera</order>
#     <family>vespertilionidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio24625</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>lilium occidentale</scientific_name>
#     <common_name>western lily</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>vascular plant</category>
#     <order>liliales</order>
#     <family>liliaceae</family>
#     <state>ca</state>
#   </species>
#   <species>
#     <id>bio01978</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>anas wyvilliana</scientific_name>
#     <common_name>koloa|hawaiian duck</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>anseriformes</order>
#     <family>anatidae</family>
#     <state>hi</state>
#   </species>
#   <species>
#     <id>bio07055</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>campephilus principalis</scientific_name>
#     <common_name>ivory-billed woodpecker</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>piciformes</order>
#     <family>picidae</family>
#     <state>sc|fl</state>
#   </species>
#   <species>
#     <id>bio04352</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>astragalus phoenix</scientific_name>
#     <common_name>ash meadows milkvetch|ash meadows milk-vetch</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>threatened</listing_status>
#     <category>vascular plant</category>
#     <order>fabales</order>
#     <family>fabaceae</family>
#     <state>ca|nv</state>
#   </species>
#   <species>
#     <id>bio18454</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>gambusia gaigei</scientific_name>
#     <common_name>big bend gambusia</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>2</region>
#     <region_name>southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>fish</category>
#     <order>cyprinodontiformes</order>
#     <family>poeciliidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio12569</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>cynomys parvidens</scientific_name>
#     <common_name>utah prairie dog</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>6</region>
#     <region_name>mountain-prairie</region_name>
#     <listing_status>threatened</listing_status>
#     <category>mammal</category>
#     <order>rodentia</order>
#     <family>sciuridae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio16939</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>eucyclogobius newberryi</scientific_name>
#     <common_name>tidewater goby</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>fish</category>
#     <order>perciformes</order>
#     <family>gobiidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio13135</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>deltistes luxatus</scientific_name>
#     <common_name>lost river sucker</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>fish</category>
#     <order>cypriniformes</order>
#     <family>catostomidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio21090</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>hybognathus amarus</scientific_name>
#     <common_name>rio grande silvery minnow</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>2</region>
#     <region_name>southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>fish</category>
#     <order>cypriniformes</order>
#     <family>cyprinidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio23265</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>lampsilis abrupta</scientific_name>
#     <common_name>pink mucket</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>3</region>
#     <region_name>midwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>invertebrate</category>
#     <order>unionoida</order>
#     <family>unionidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio45023</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>vermivora bachmanii</scientific_name>
#     <common_name>bachman's wood warbler|bachman's warbler</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>passeriformes</order>
#     <family>parulidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio28124</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>mustela nigripes</scientific_name>
#     <common_name>black-footed ferret|ferret|black-footed</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>6</region>
#     <region_name>mountain-prairie</region_name>
#     <listing_status>endangered</listing_status>
#     <category>mammal</category>
#     <order>carnivora</order>
#     <family>mustelidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio19413</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>grus americana</scientific_name>
#     <common_name>whooping crane</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>2</region>
#     <region_name>southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>gruiformes</order>
#     <family>gruidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio36335</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>pterodroma sandwichensis</scientific_name>
#     <common_name>hawaiian petrel|hawaiian dark-rumped petrel|`ua`u</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>procellariiformes</order>
#     <family>procellariidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio02701</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>aphelocoma coerulescens</scientific_name>
#     <common_name>florida scrub jay|scrub jay|florida scrub-jay</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>threatened</listing_status>
#     <category>bird</category>
#     <order>passeriformes</order>
#     <family>corvidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio25447</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>loxops coccineus</scientific_name>
#     <common_name>hawai'i' 'akepa</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>passeriformes</order>
#     <family>fringillidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio33630</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>picoides borealis</scientific_name>
#     <common_name>red-cockaded woodpecker</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>piciformes</order>
#     <family>picidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio31051</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>palmeria dolei</scientific_name>
#     <common_name>akohekohe|crested honeycreeper</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>passeriformes</order>
#     <family>fringillidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio09194</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>chasmistes liorus</scientific_name>
#     <common_name>june sucker</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>6</region>
#     <region_name>mountain-prairie</region_name>
#     <listing_status>endangered</listing_status>
#     <category>fish</category>
#     <order>cypriniformes</order>
#     <family>catostomidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio21763</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>hypomesus transpacificus</scientific_name>
#     <common_name>delta smelt</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>threatened</listing_status>
#     <category>fish</category>
#     <order>osmeriformes</order>
#     <family>osmeridae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio03113</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>arctomecon humilis</scientific_name>
#     <common_name>dwarf bear poppy|common bearpoppy|dwarf bearpoppy</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>6</region>
#     <region_name>mountain-prairie</region_name>
#     <listing_status>endangered</listing_status>
#     <category>vascular plant</category>
#     <order>ranunculales</order>
#     <family>papaveraceae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio37053</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>rana pretiosa</scientific_name>
#     <common_name>oregon spotted frog|spotted frog</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>threatened</listing_status>
#     <category>amphibian</category>
#     <order>anura</order>
#     <family>ranidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio10741</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>coccyzus americanus</scientific_name>
#     <common_name>eastern yellow-billed cuckoo|yellow-billed cuckoo|rain crow|storm crow</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>2</region>
#     <region_name>southwest</region_name>
#     <listing_status>threatened</listing_status>
#     <category>bird</category>
#     <order>cuculiformes</order>
#     <family>cuculidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio19261</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>gopherus polyphemus</scientific_name>
#     <common_name>gopher tortoise</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>under review|threatened</listing_status>
#     <category>reptile</category>
#     <order>testudines</order>
#     <family>testudinidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio19259</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>gopherus agassizii</scientific_name>
#     <common_name>agassiz's desert tortoise|mojave desert tortoise|mohave desert tortoise|desert tortoise</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>8</region>
#     <region_name>pacific southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>reptile</category>
#     <order>testudines</order>
#     <family>testudinidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio29607</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>obovaria retusa</scientific_name>
#     <common_name>ring pink|ring pink mussel|golf stick pearly mussel</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>endangered</listing_status>
#     <category>invertebrate</category>
#     <order>unionoida</order>
#     <family>unionidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio34395</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>pleurobema plenum</scientific_name>
#     <common_name>rough pigtoe|rough pigtoe pearly mussel</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>4</region>
#     <region_name>southeast</region_name>
#     <listing_status>endangered</listing_status>
#     <category>invertebrate</category>
#     <order>unionoida</order>
#     <family>unionidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio34392</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>pleurobema clava</scientific_name>
#     <common_name>clubshell|club naiad|clubshell pearly mussel</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>5</region>
#     <region_name>northeast</region_name>
#     <listing_status>endangered</listing_status>
#     <category>invertebrate</category>
#     <order>unionoida</order>
#     <family>unionidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio29617</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>oceanodroma castro</scientific_name>
#     <common_name>band-rumped storm petrel|`ake`ake|band-rumped storm-petrel|akeake|madeiran storm petrel|harcourt's storm petrel</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>procellariiformes</order>
#     <family>hydrobatidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio36090</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>pseudonestor xanthophrys</scientific_name>
#     <common_name>maui parrotbill|kiwikiu</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>passeriformes</order>
#     <family>fringillidae</family>
#     <state>hi</state>
#   </species>
#   <species>
#     <id>bio08558</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>centrocercus minimus</scientific_name>
#     <common_name>gunnison grouse|gunnison sage-grouse|lesser sage-grouse</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>6</region>
#     <region_name>mountain-prairie</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>galliformes</order>
#     <family>phasianidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio05812</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>brachyramphus marmoratus</scientific_name>
#     <common_name>marbled murrelet|long-billed murrelet</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>threatened</listing_status>
#     <category>bird</category>
#     <order>charadriiformes</order>
#     <family>alcidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>es1509</id>
#     <provenance>fws-endangeredspecies</provenance>
#     <scientific_name>megalagrion nesiotes</scientific_name>
#     <common_name>flying earwig hawaiian damselfly</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>insect</category>
#     <order>odonata</order>
#     <family>coenagrionidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>es1185</id>
#     <provenance>fws-endangeredspecies</provenance>
#     <scientific_name>megalagrion pacificum</scientific_name>
#     <common_name>pacific hawaiian damselfly</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>insect</category>
#     <order>odonata</order>
#     <family>coenagrionidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>es1140</id>
#     <provenance>fws-endangeredspecies</provenance>
#     <scientific_name>megalagrion xanthomelas</scientific_name>
#     <common_name>orangeblack hawaiian damselfly</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>insect</category>
#     <order>odonata</order>
#     <family>coenagrionidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>es1179</id>
#     <provenance>fws-endangeredspecies</provenance>
#     <scientific_name>psittirostra psittacea</scientific_name>
#     <common_name>`o`u|honeycreeper</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>passeriformes</order>
#     <family>fringillidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio09158</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>charadrius melodus</scientific_name>
#     <common_name>piping plover|eastern piping plover</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>0|1</region>
#     <region_name>northeast|midwest</region_name>
#     <listing_status>threatened</listing_status>
#     <category>bird</category>
#     <order>charadriiformes</order>
#     <family>charadriidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio40443</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>sistrurus catenatus</scientific_name>
#     <common_name>massasauga|desert massasauga</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>3</region>
#     <region_name>midwest</region_name>
#     <listing_status>proposed threatened</listing_status>
#     <category>reptile</category>
#     <order>squamata</order>
#     <family>viperidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio25449</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>loxops ochraceus</scientific_name>
#     <common_name>maui 'akepa</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>1</region>
#     <region_name>pacific</region_name>
#     <listing_status>endangered</listing_status>
#     <category>bird</category>
#     <order>passeriformes</order>
#     <family>fringillidae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio14927</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>echinomastus mariposensis</scientific_name>
#     <common_name>lloyd's mariposa cactus|lloyd's fishhook cactus|golfball cactus|silver column cactus|mariposa cactus</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>2</region>
#     <region_name>southwest</region_name>
#     <listing_status>threatened</listing_status>
#     <category>vascular plant</category>
#     <order>caryophyllales</order>
#     <family>cactaceae</family>
#     <state/>
#   </species>
#   <species>
#     <id>bio42131</id>
#     <provenance>biodiversityusnationalparks</provenance>
#     <scientific_name>stygoparnus comalensis</scientific_name>
#     <common_name>comal springs dryopid beetle</common_name>
#     <label/>
#     <where_listed/>
#     <different_from/>
#     <endemic_to/>
#     <region>2</region>
#     <region_name>southwest</region_name>
#     <listing_status>endangered</listing_status>
#     <category>insect</category>
#     <order>coleoptera</order>
#     <family>dryopidae</family>
#     <state/>
#   </species>
# </animals_and_plants>

# %%
def convert_to_xml_species(row, output_file):
    
    # add species opening tag to xml string
    xml_species = ['<Species>']
    
    # get ID from the row
    ident = row['id']
    #create ID string with attribute value by substituting {} with ident
    xml_species.append('  <ID>{}</ID>'.format(ident))
                
    # get provenance from the row
    provenance = row['provenance']
    #create Provenance string with attribute value by substituting {} with ident
    xml_species.append('  <Provenance>{}</Provenance>'.format(provenance))

    
    # get scientific name from the row
    scientific_name = row['scientific_name']
    #create scientific_name string with attribute value by substituting {} with scientific_name
    xml_species.append('  <Scientific_Name>{}</Scientific_Name>'.format(scientific_name))
    
    # get common name from the row
    common_name = row['common_name']
    #create common_name string with attribute value by substituting {} with common_name
    xml_species.append('  <Common_Names>')
    xml_species.append('    <Common_Name>{}</Common_Name>'.format(common_name))
    xml_species.append('  </Common_Names>')

    
    # cast list string back to a list object
    # and check if attribute is of type string, if not cast to string
    if not isinstance(row['where_listed'], str):
        where_listed_list = str(row['where_listed']).split('|')
    else:
        where_listed_list = row['where_listed'].split('|')
    ## here the conversion to XML of the list attributes
    xml_species.append('  <Where_Listeds>')
    for i in range(len(where_listed_list)):
        # get where_listed from the list element
        where_listed = where_listed_list[i]
        #create common_name string with attribute value by substituting {} with common_name
        xml_species.append('    <Where_Listed>{}</Where_Listed>'.format(where_listed))
    xml_species.append('  </Where_Listeds>')
        
    # cast list string back to a list object
    # and check if attribute is of type string, if not cast to string
    if not isinstance(row['region'], str):
        region_list = str(row['region']).split('|')
    else:
        region_list = row['region'].split('|')
    ## here the conversion to XML of the list attributes
    xml_species.append('  <Regions>')
    for i in range(len(region_list)):
        # get where_listed from the list element
        region = region_list[i]
        #create common_name string with attribute value by substituting {} with region
        xml_species.append('    <Region>{}</Region>'.format(region))
    xml_species.append('  </Regions>')
      
    # cast list string back to a list object
    region_name_list = row['region_name'].split('|')
    ## here the conversion to XML of the list attributes
    xml_species.append('  <Region_Names>')
    for i in range(len(region_name_list)):
        # get where_listed from the list element
        region_name = region_name_list[i]
        #create common_name string with attribute value by substituting {} with region_name
        xml_species.append('    <Region_Name>{}</Region_Name>'.format(region_name))
    xml_species.append('  </Region_Names>')
   
    # cast list string back to a list object
    listing_status_list = row['listing_status'].split('|')
    ## here the conversion to XML of the list attributes
    xml_species.append('  <Listing_Statuses>')
    for i in range(len(listing_status_list)):
        # get where_listed from the list element
        listing_status = listing_status_list[i]
        #create common_name string with attribute value by substituting {} with region_name
        xml_species.append('    <Listing_Status>{}</Listing_Status>'.format(listing_status))
    xml_species.append('  </Listing_Statuses>')
    
    # get category from the row
    category = row['category']
    #create category string with attribute value by substituting {} with category
    xml_species.append('<Category>{}</Category>'.format(category))
    
    # add species closing tag to xml string
    xml_species.append('</Species>')
  
    species_element = '\n'.join(xml_species)
    #print(species_element)
    
    # open output file
    f = open(output_file, "a")
    # write to output file
    f.write(species_element + "\n")
    
    return row

# %%
# define the destination file
goldstandard_xml = "../xml/goldstandard_xml.xml"

# open fiele with writing, thus the current file is overwritten
f = open(goldstandard_xml, "w")
# write the start of the XML document
f.write("<?xml version='1.0' encoding='utf-8'?>\n<Animals_And_Plants>\n")
f.close()

# run the function and give it the destination file as attribute
# it will append any species elements to the file, without overwriting
# the existing information
gs.apply(lambda row: convert_to_xml_species(row, goldstandard_xml), axis =1)

# append the closing tag of the XML to the document
f = open(goldstandard_xml, "a")
f.write("</Animals_And_Plants>")
f.close()
