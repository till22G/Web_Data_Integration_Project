# %%
import pandas as pd
import os

# %%
path_to_data_dir = '../data'
# endangered species
df_es = pd.read_csv(os.path.join(path_to_data_dir, 'species-listings-by-tax-group-report_animals_and_plants.csv'))
# natural park species
df_sp = pd.read_csv(os.path.join(path_to_data_dir, 'species.csv'))
# wikidata mammals
df_wd = pd.read_csv(os.path.join(path_to_data_dir, 'wd_mammals.csv'))
# Out:
# /Users/robertbluemel/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_es
# Out:
#       Unnamed: 0                   Scientific Name  \
# 0              0              Drosophila differens
# 1              1  Ammodramus savannarum floridanus
# 2              2          Nerodia clarkii taeniata
# 3              3             Corvus leucognaphalus
# 4              4                Fusconaia cuneolus
# ...          ...                               ...
# 1653         933               Packera franciscana
# 1654         934               Trillium persistens
# 1655         935     Pritchardia aylmer-robinsonii
# 1656         936              Festuca molokaiensis
# 1657         937            Psychotria grandiflora
#
#                       Common Name  \
# 0       Hawaiian picture-wing fly
# 1     Florida grasshopper sparrow
# 2       Atlantic salt marsh snake
# 3               White-necked crow
# 4                Finerayed pigtoe
# ...                           ...
# 1653  San Francisco Peaks ragwort
# 1654          Persistent trillium
# ...

# %%
df_sp
# Out:
#        Species ID             Park Name        Category          Order  \
# 0       ACAD-1000  Acadia National Park          Mammal   Artiodactyla
# 1       ACAD-1001  Acadia National Park          Mammal   Artiodactyla
# 2       ACAD-1002  Acadia National Park          Mammal      Carnivora
# 3       ACAD-1003  Acadia National Park          Mammal      Carnivora
# 4       ACAD-1004  Acadia National Park          Mammal      Carnivora
# ...           ...                   ...             ...            ...
# 119243  ZION-2791    Zion National Park  Vascular Plant      Solanales
# 119244  ZION-2792    Zion National Park  Vascular Plant        Vitales
# 119245  ZION-2793    Zion National Park  Vascular Plant        Vitales
# 119246  ZION-2794    Zion National Park  Vascular Plant  Zygophyllales
# 119247  ZION-2795    Zion National Park  Vascular Plant  Zygophyllales
#
#                 Family         Scientific Name  \
# 0             Cervidae             Alces alces
# ...

# %%
df_wd
# Out:
#                                      resource  \
# 0      http://www.wikidata.org/entity/Q220213
# 1      http://www.wikidata.org/entity/Q220213
# 2      http://www.wikidata.org/entity/Q220213
# 3      http://www.wikidata.org/entity/Q220213
# 4      http://www.wikidata.org/entity/Q220213
# ...                                       ...
# 13182     http://www.wikidata.org/entity/Q144
# 13183     http://www.wikidata.org/entity/Q144
# 13184     http://www.wikidata.org/entity/Q144
# 13185     http://www.wikidata.org/entity/Q144
# 13186     http://www.wikidata.org/entity/Q144
#
#                                   superClass  \
# 0       http://www.wikidata.org/entity/Q7368
# 1       http://www.wikidata.org/entity/Q7368
# 2       http://www.wikidata.org/entity/Q7368
# 3       http://www.wikidata.org/entity/Q7368
# 4       http://www.wikidata.org/entity/Q7368
# ...                                      ...
# 13182  http://www.wikidata.org/entity/Q39201
# ...
