# %%
# Data processing of the "FWS-Listed U.S. Species by Taxonomic Group" dataset
# https://www.fws.gov/endangered/species/index.html

# importing packages
import pandas as pd
import lxml

pd.__version__
# Out:
# '1.3.4'

# %%
# merging .csv files
df = pd.concat(map(pd.read_csv, ['../Data/species-listings-by-tax-group-report_plants.csv', '../Data/species-listings-by-tax-group-report_animals.csv']), ignore_index=True)


# add ID column based on dataset identifier(ES <- Endangered Species) and index
df.insert(0, 'ID', 'ES' + df.index.astype(str))


# change column names (spaces to underscore, lower case, "group" to "category"
df = df.rename(columns={"Group": "category"})
df.columns = [c.replace(' ', '_') for c in df.columns]
df.columns = df.columns.str.lower()


# add a column with region names based on "region" number
dicRegionNames = {1: "Pacific", 2: "Southwest", 3: "Midwest", 4: "Southeast", 5: "Northeast", 6: "Mountain-Prairie", 7: "Alaska", 8: "Pacific Southwest"}
df.insert(4, 'region_name', df['region'].map(dicRegionNames))


# drop all values with special "ESA Listing Status" (72 entries in total)
df = df[df.esa_listing_status != 'Experimental Population, Non-Essential'] #(64 entries)
df = df[df.esa_listing_status != 'Similarity of Appearance (Threatened)'] #(8 entries)


# drop duplicates based on "scientific_name", but keep the first entry
#df.drop_duplicates(subset = ['scientific_name'], keep = 'first')


# drop "Where Listed" column from DataFrame
#df = df.drop('WhereListed', 1)

print(df.head())
# Out:
#     id                       scientific_name        common_name  \
# 0  ES0                Pediocactus knowltonii  Knowlton's cactus
# 1  ES1                   Schiedea sarmentosa     No common name
# 2  ES2     Deinandra increscens ssp. villosa   Gaviota Tarplant
# 3  ES3                     Silene lanceolata     No common name
# 4  ES4  Bidens campylotheca ssp. waihoiensis        Ko`oko`olau
#
#      where_listed        region_name  region esa_listing_status  \
# 0  Wherever found          Southwest       2         Endangered
# 1  Wherever found            Pacific       1         Endangered
# 2  Wherever found  Pacific Southwest       8         Endangered
# 3  Wherever found            Pacific       1         Endangered
# 4  Wherever found            Pacific       1         Endangered
#
#            category
# 0  Flowering Plants
# 1  Flowering Plants
# 2  Flowering Plants
# 3  Flowering Plants
# 4  Flowering Plants

# %%
# save DataFrame to .xml
#df.to_xml('../xml/endangered-species.xml', index=False, root_name='animals_and_plants', row_name='species')
print(df.to_xml(index=False, root_name='animals_and_plants', row_name='species'))
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <animals_and_plants>
#   <species>
#     <id>ES0</id>
#     <scientific_name>Pediocactus knowltonii</scientific_name>
#     <common_name>Knowlton's cactus</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES1</id>
#     <scientific_name>Schiedea sarmentosa</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES2</id>
#     <scientific_name>Deinandra increscens ssp. villosa</scientific_name>
#     <common_name>Gaviota Tarplant</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES3</id>
#     <scientific_name>Silene lanceolata</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES4</id>
#     <scientific_name>Bidens campylotheca ssp. waihoiensis</scientific_name>
#     <common_name>Ko`oko`olau</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES5</id>
#     <scientific_name>Remya mauiensis</scientific_name>
#     <common_name>Maui remya</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES6</id>
#     <scientific_name>Keysseria (=Lagenifera) helenae</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES7</id>
#     <scientific_name>Orcuttia tenuis</scientific_name>
#     <common_name>Slender Orcutt grass</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES8</id>
#     <scientific_name>Calyptranthes thomasiana</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES9</id>
#     <scientific_name>Peucedanum sandwicense</scientific_name>
#     <common_name>Makou</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES10</id>
#     <scientific_name>Astragalus osterhoutii</scientific_name>
#     <common_name>Osterhout milkvetch</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Mountain-Prairie</region_name>
#     <region>6</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES11</id>
#     <scientific_name>Amaranthus pumilus</scientific_name>
#     <common_name>Seabeach amaranth</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES12</id>
#     <scientific_name>Schiedea viscosa</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES13</id>
#     <scientific_name>Astragalus lentiginosus var. piscinensis</scientific_name>
#     <common_name>Fish Slough milk-vetch</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES14</id>
#     <scientific_name>Erysimum teretifolium</scientific_name>
#     <common_name>Ben Lomond wallflower</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES15</id>
#     <scientific_name>Abutilon sandwicense</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES16</id>
#     <scientific_name>Solanum incompletum</scientific_name>
#     <common_name>Popolo ku mai</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES17</id>
#     <scientific_name>Thelypteris verecunda</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Ferns and Allies</category>
#   </species>
#   <species>
#     <id>ES18</id>
#     <scientific_name>Cyanea glabra</scientific_name>
#     <common_name>Haha</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES19</id>
#     <scientific_name>Conradina glabra</scientific_name>
#     <common_name>Apalachicola rosemary</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES20</id>
#     <scientific_name>Labordia helleri</scientific_name>
#     <common_name>Kamakahala</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES21</id>
#     <scientific_name>Asplenium peruvianum var. insulare</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Ferns and Allies</category>
#   </species>
#   <species>
#     <id>ES22</id>
#     <scientific_name>Platydesma cornuta var. decurrens</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES23</id>
#     <scientific_name>Delphinium luteum</scientific_name>
#     <common_name>Yellow larkspur</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES24</id>
#     <scientific_name>Cyrtandra crenata</scientific_name>
#     <common_name>Ha`iwale</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES25</id>
#     <scientific_name>Euphorbia herbstii</scientific_name>
#     <common_name>`Akoko</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES26</id>
#     <scientific_name>Schiedea kealiae</scientific_name>
#     <common_name>Ma`oli`oli</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES27</id>
#     <scientific_name>Lesquerella kingii ssp. bernardina</scientific_name>
#     <common_name>San Bernardino Mountains bladderpod</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES28</id>
#     <scientific_name>Sclerocactus wetlandicus</scientific_name>
#     <common_name>Uinta Basin hookless cactus</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Mountain-Prairie</region_name>
#     <region>6</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES29</id>
#     <scientific_name>Bidens conjuncta</scientific_name>
#     <common_name>Ko`oko`olau</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES30</id>
#     <scientific_name>Marshallia mohrii</scientific_name>
#     <common_name>Mohr's Barbara's buttons</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES31</id>
#     <scientific_name>Lessingia germanorum (=L.g. var. germanorum)</scientific_name>
#     <common_name>San Francisco lessingia</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES32</id>
#     <scientific_name>Pleomele hawaiiensis</scientific_name>
#     <common_name>Hala pepe</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES33</id>
#     <scientific_name>Cirsium hydrophilum var. hydrophilum</scientific_name>
#     <common_name>Suisun thistle</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES34</id>
#     <scientific_name>Lesquerella thamnophila</scientific_name>
#     <common_name>Zapata bladderpod</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES35</id>
#     <scientific_name>Varronia rupicola</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES36</id>
#     <scientific_name>Eryngium cuneifolium</scientific_name>
#     <common_name>Snakeroot</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES37</id>
#     <scientific_name>Stenogyne bifida</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES38</id>
#     <scientific_name>Navarretia leucocephala ssp. plieantha</scientific_name>
#     <common_name>Many-flowered navarretia</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES39</id>
#     <scientific_name>Cyrtandra subumbellata</scientific_name>
#     <common_name>Ha`iwale</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES40</id>
#     <scientific_name>Acanthomintha obovata ssp. duttonii</scientific_name>
#     <common_name>San Mateo thornmint</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES41</id>
#     <scientific_name>Ceanothus ophiochilus</scientific_name>
#     <common_name>Vail Lake ceanothus</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES42</id>
#     <scientific_name>Linum carteri carteri</scientific_name>
#     <common_name>Carter's small-flowered flax</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES43</id>
#     <scientific_name>Myrsine fosbergii</scientific_name>
#     <common_name>Kolea</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES44</id>
#     <scientific_name>Deinandra (=Hemizonia) conjugens</scientific_name>
#     <common_name>Otay tarplant</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES45</id>
#     <scientific_name>Arctomecon humilis</scientific_name>
#     <common_name>Dwarf Bear-poppy</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Mountain-Prairie</region_name>
#     <region>6</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES46</id>
#     <scientific_name>Pritchardia bakeri</scientific_name>
#     <common_name>loulu</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES47</id>
#     <scientific_name>Spiranthes diluvialis</scientific_name>
#     <common_name>Ute ladies'-tresses</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Mountain-Prairie</region_name>
#     <region>6</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES48</id>
#     <scientific_name>Helianthus verticillatus</scientific_name>
#     <common_name>Whorled Sunflower</common_name>
#     <where_listed/>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES49</id>
#     <scientific_name>Gesneria pauciflora</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES50</id>
#     <scientific_name>Isoetes louisianensis</scientific_name>
#     <common_name>Louisiana quillwort</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Ferns and Allies</category>
#   </species>
#   <species>
#     <id>ES51</id>
#     <scientific_name>Astragalus jaegerianus</scientific_name>
#     <common_name>Lane Mountain milk-vetch</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES52</id>
#     <scientific_name>Eugenia bryanii</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES53</id>
#     <scientific_name>Clematis socialis</scientific_name>
#     <common_name>Alabama leather flower</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES54</id>
#     <scientific_name>Campanula robinsiae</scientific_name>
#     <common_name>Brooksville bellflower</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES55</id>
#     <scientific_name>Pritchardia remota</scientific_name>
#     <common_name>loulu</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES56</id>
#     <scientific_name>Pritchardia lanigera</scientific_name>
#     <common_name>loulu</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES57</id>
#     <scientific_name>Lipochaeta venosa</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES58</id>
#     <scientific_name>Polyscias bisattenuata</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES59</id>
#     <scientific_name>Cyrtandra wagneri</scientific_name>
#     <common_name>haiwale</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES60</id>
#     <scientific_name>Tetramolopium filiforme</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES61</id>
#     <scientific_name>Bidens hillebrandiana ssp. hillebrandiana</scientific_name>
#     <common_name>kookoolau</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES62</id>
#     <scientific_name>Thelypteris yaucoensis</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Ferns and Allies</category>
#   </species>
#   <species>
#     <id>ES63</id>
#     <scientific_name>Isodendrion laurifolium</scientific_name>
#     <common_name>Aupaka</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES64</id>
#     <scientific_name>Cyanea gibsonii</scientific_name>
#     <common_name>haha</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES65</id>
#     <scientific_name>Cirsium pitcheri</scientific_name>
#     <common_name>Pitcher's thistle</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Midwest</region_name>
#     <region>3</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES66</id>
#     <scientific_name>Leavenworthia crassa</scientific_name>
#     <common_name>Fleshy-fruit gladecress</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES67</id>
#     <scientific_name>Dubautia imbricata ssp. imbricata</scientific_name>
#     <common_name>Na`ena`e</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES68</id>
#     <scientific_name>Lilaeopsis schaffneriana var. recurva</scientific_name>
#     <common_name>Huachuca water-umbel</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES69</id>
#     <scientific_name>Lesquerella perforata</scientific_name>
#     <common_name>Spring Creek bladderpod</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES70</id>
#     <scientific_name>Astragalus brauntonii</scientific_name>
#     <common_name>Braunton's milk-vetch</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES71</id>
#     <scientific_name>Platydesma rostrata</scientific_name>
#     <common_name>Pilo kea lau li`i</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES72</id>
#     <scientific_name>Cyrtandra viridiflora</scientific_name>
#     <common_name>Ha`iwale</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES73</id>
#     <scientific_name>Geranium hanaense</scientific_name>
#     <common_name>Nohoanu</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES74</id>
#     <scientific_name>Stenogyne kanehoana</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES75</id>
#     <scientific_name>Phacelia formosula</scientific_name>
#     <common_name>North Park phacelia</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Mountain-Prairie</region_name>
#     <region>6</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES76</id>
#     <scientific_name>Pritchardia schattaueri</scientific_name>
#     <common_name>loulu</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES77</id>
#     <scientific_name>Hoffmannseggia tenella</scientific_name>
#     <common_name>Slender rush-pea</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES78</id>
#     <scientific_name>Cyathea dryopteroides</scientific_name>
#     <common_name>Elfin tree fern</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Ferns and Allies</category>
#   </species>
#   <species>
#     <id>ES79</id>
#     <scientific_name>Spigelia gentianoides</scientific_name>
#     <common_name>Gentian pinkroot</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES80</id>
#     <scientific_name>Schiedea hawaiiensis</scientific_name>
#     <common_name>Ma`oli`oli</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES81</id>
#     <scientific_name>Vicia menziesii</scientific_name>
#     <common_name>Hawaiian vetch</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES82</id>
#     <scientific_name>Trillium reliquum</scientific_name>
#     <common_name>Relict trillium</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES83</id>
#     <scientific_name>Chorizanthe valida</scientific_name>
#     <common_name>Sonoma spineflower</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES84</id>
#     <scientific_name>Chorizanthe howellii</scientific_name>
#     <common_name>Howell's spineflower</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES85</id>
#     <scientific_name>Thelypodium howellii ssp. spectabilis</scientific_name>
#     <common_name>Howell''s spectacular thelypody</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES86</id>
#     <scientific_name>Orcuttia californica</scientific_name>
#     <common_name>California Orcutt grass</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES87</id>
#     <scientific_name>Malacothamnus clementinus</scientific_name>
#     <common_name>San Clemente Island bush-mallow</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES88</id>
#     <scientific_name>Orcuttia inaequalis</scientific_name>
#     <common_name>San Joaquin Orcutt grass</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES89</id>
#     <scientific_name>Phyllostegia parviflora</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES90</id>
#     <scientific_name>Scutellaria floridana</scientific_name>
#     <common_name>Florida skullcap</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES91</id>
#     <scientific_name>Flueggea neowawraea</scientific_name>
#     <common_name>Mehamehame</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES92</id>
#     <scientific_name>Euphorbia remyi var. kauaiensis</scientific_name>
#     <common_name>`Akoko</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES93</id>
#     <scientific_name>Phyllostegia racemosa</scientific_name>
#     <common_name>Kiponapona</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES94</id>
#     <scientific_name>Myrsine linearifolia</scientific_name>
#     <common_name>Kolea</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES95</id>
#     <scientific_name>Euphorbia haeleeleana</scientific_name>
#     <common_name>`Akoko</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES96</id>
#     <scientific_name>Sicyos albus</scientific_name>
#     <common_name>`Anunu</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES97</id>
#     <scientific_name>Calochortus tiburonensis</scientific_name>
#     <common_name>Tiburon mariposa lily</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES98</id>
#     <scientific_name>Suaeda californica</scientific_name>
#     <common_name>California seablite</common_name>
#     <where_listed/>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES99</id>
#     <scientific_name>Leavenworthia exigua laciniata</scientific_name>
#     <common_name>Kentucky glade cress</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES100</id>
#     <scientific_name>Isotria medeoloides</scientific_name>
#     <common_name>Small whorled pogonia</common_name>
#     <where_listed/>
#     <region_name>Northeast</region_name>
#     <region>5</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES101</id>
#     <scientific_name>Dudleya verityi</scientific_name>
#     <common_name>Verity's dudleya</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES102</id>
#     <scientific_name>Pentachaeta bellidiflora</scientific_name>
#     <common_name>White-rayed pentachaeta</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES103</id>
#     <scientific_name>Sidalcea keckii</scientific_name>
#     <common_name>Keck's Checker-mallow</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES104</id>
#     <scientific_name>Pogogyne abramsii</scientific_name>
#     <common_name>San Diego mesa-mint</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES105</id>
#     <scientific_name>Lobelia monostachya</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES106</id>
#     <scientific_name>Astragalus cremnophylax var. cremnophylax</scientific_name>
#     <common_name>Sentry milk-vetch</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES107</id>
#     <scientific_name>Asplenium dielmannii</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Ferns and Allies</category>
#   </species>
#   <species>
#     <id>ES108</id>
#     <scientific_name>Navarretia fossalis</scientific_name>
#     <common_name>Spreading navarretia</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES109</id>
#     <scientific_name>Piperia yadonii</scientific_name>
#     <common_name>Yadon's piperia</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES110</id>
#     <scientific_name>Cyrtandra sessilis</scientific_name>
#     <common_name>Ha`iwale</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES111</id>
#     <scientific_name>Phyllostegia wawrana</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES112</id>
#     <scientific_name>Cordylanthus maritimus ssp. maritimus</scientific_name>
#     <common_name>Salt marsh bird's-beak</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES113</id>
#     <scientific_name>Stenogyne kealiae</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES114</id>
#     <scientific_name>Exocarpos luteolus</scientific_name>
#     <common_name>Heau</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES115</id>
#     <scientific_name>Arctostaphylos confertiflora</scientific_name>
#     <common_name>Santa Rosa Island manzanita</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES116</id>
#     <scientific_name>Melicope lydgatei</scientific_name>
#     <common_name>Alani</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES117</id>
#     <scientific_name>Deeringothamnus pulchellus</scientific_name>
#     <common_name>Beautiful pawpaw</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES118</id>
#     <scientific_name>Galium californicum ssp. sierrae</scientific_name>
#     <common_name>El Dorado bedstraw</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES119</id>
#     <scientific_name>Cyanea purpurellifolia</scientific_name>
#     <common_name>Haha</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES120</id>
#     <scientific_name>Melicope knudsenii</scientific_name>
#     <common_name>Alani</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES121</id>
#     <scientific_name>Galium buxifolium</scientific_name>
#     <common_name>Island bedstraw</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES122</id>
#     <scientific_name>Opuntia treleasei</scientific_name>
#     <common_name>Bakersfield cactus</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES123</id>
#     <scientific_name>Schiedea spergulina var. leiopoda</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES124</id>
#     <scientific_name>Tuberolabium guamense</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES125</id>
#     <scientific_name>Serianthes nelsonii</scientific_name>
#     <common_name>Hayun Iagu (=(Guam), Tronkon guafi (Rota))</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES126</id>
#     <scientific_name>Mimulus michiganensis</scientific_name>
#     <common_name>Michigan monkey-flower</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Midwest</region_name>
#     <region>3</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES127</id>
#     <scientific_name>Urera kaalae</scientific_name>
#     <common_name>Opuhe</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES128</id>
#     <scientific_name>Melicope hiiakae</scientific_name>
#     <common_name>Alani</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES129</id>
#     <scientific_name>Holocarpha macradenia</scientific_name>
#     <common_name>Santa Cruz tarplant</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES130</id>
#     <scientific_name>Schiedea attenuata</scientific_name>
#     <common_name>No common name</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES131</id>
#     <scientific_name>Argyroxiphium kauense</scientific_name>
#     <common_name>Mauna Loa (=Ka'u) silversword</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Flowering Plants</category>
#   </species>
#   <species>
#     <id>ES132</id>
# ...
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Birds</category>
#   </species>
#   <species>
#     <id>ES1611</id>
#     <scientific_name>Antrobia culveri</scientific_name>
#     <common_name>Tumbling Creek cavesnail</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Midwest</region_name>
#     <region>3</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Snails</category>
#   </species>
#   <species>
#     <id>ES1612</id>
#     <scientific_name>Leptoxis foremani</scientific_name>
#     <common_name>Interrupted (=Georgia) Rocksnail</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Snails</category>
#   </species>
#   <species>
#     <id>ES1613</id>
#     <scientific_name>Peromyscus polionotus trissyllepsis</scientific_name>
#     <common_name>Perdido Key beach mouse</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1614</id>
#     <scientific_name>Pteropus mariannus mariannus</scientific_name>
#     <common_name>Mariana fruit Bat (=Mariana flying fox)</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1615</id>
#     <scientific_name>Branchinecta longiantenna</scientific_name>
#     <common_name>Longhorn fairy shrimp</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Crustaceans</category>
#   </species>
#   <species>
#     <id>ES1616</id>
#     <scientific_name>Panthera onca</scientific_name>
#     <common_name>Jaguar</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1617</id>
#     <scientific_name>Drosophila mulli</scientific_name>
#     <common_name>Hawaiian picture-wing fly</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Insects</category>
#   </species>
#   <species>
#     <id>ES1619</id>
#     <scientific_name>Drymarchon corais couperi</scientific_name>
#     <common_name>Eastern indigo snake</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Reptiles</category>
#   </species>
#   <species>
#     <id>ES1620</id>
#     <scientific_name>Glaucomys sabrinus coloratus</scientific_name>
#     <common_name>Carolina northern flying squirrel</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1621</id>
#     <scientific_name>Manduca blackburni</scientific_name>
#     <common_name>Blackburn's sphinx moth</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Insects</category>
#   </species>
#   <species>
#     <id>ES1622</id>
#     <scientific_name>Tryonia circumstriata (=stocktonensis)</scientific_name>
#     <common_name>Gonzales tryonia</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Snails</category>
#   </species>
#   <species>
#     <id>ES1623</id>
#     <scientific_name>Branchinecta conservatio</scientific_name>
#     <common_name>Conservancy fairy shrimp</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Crustaceans</category>
#   </species>
#   <species>
#     <id>ES1624</id>
#     <scientific_name>Empidonax traillii extimus</scientific_name>
#     <common_name>Southwestern willow flycatcher</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Birds</category>
#   </species>
#   <species>
#     <id>ES1625</id>
#     <scientific_name>Gasterosteus aculeatus williamsoni</scientific_name>
#     <common_name>Unarmored threespine stickleback</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Fishes</category>
#   </species>
#   <species>
#     <id>ES1626</id>
#     <scientific_name>Strix occidentalis lucida</scientific_name>
#     <common_name>Mexican spotted owl</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Birds</category>
#   </species>
#   <species>
#     <id>ES1627</id>
#     <scientific_name>Canis rufus</scientific_name>
#     <common_name>Red wolf</common_name>
#     <where_listed>Wherever found, except where listed as an experimental population</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1629</id>
#     <scientific_name>Necturus lewisi</scientific_name>
#     <common_name>Neuse River waterdog</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Amphibians</category>
#   </species>
#   <species>
#     <id>ES1630</id>
#     <scientific_name>Oryzomys palustris natator</scientific_name>
#     <common_name>Silver rice rat</common_name>
#     <where_listed>lower FL Keys</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1631</id>
#     <scientific_name>Pleurobema perovatum</scientific_name>
#     <common_name>Ovate clubshell</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Clams</category>
#   </species>
#   <species>
#     <id>ES1632</id>
#     <scientific_name>Percina pantherina</scientific_name>
#     <common_name>Leopard darter</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Fishes</category>
#   </species>
#   <species>
#     <id>ES1634</id>
#     <scientific_name>Ursus arctos horribilis</scientific_name>
#     <common_name>Grizzly bear</common_name>
#     <where_listed>U.S.A., conterminous (lower 48) States, except where listed as an experimental population</where_listed>
#     <region_name>Mountain-Prairie</region_name>
#     <region>6</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1635</id>
#     <scientific_name>Ursus maritimus</scientific_name>
#     <common_name>Polar bear</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Alaska</region_name>
#     <region>7</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1636</id>
#     <scientific_name>Drosophila substenoptera</scientific_name>
#     <common_name>Hawaiian picture-wing fly</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Insects</category>
#   </species>
#   <species>
#     <id>ES1637</id>
#     <scientific_name>Mycteria americana</scientific_name>
#     <common_name>Wood stork</common_name>
#     <where_listed>AL, FL, GA, MS, NC, SC</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Birds</category>
#   </species>
#   <species>
#     <id>ES1638</id>
#     <scientific_name>Microtus californicus scirpensis</scientific_name>
#     <common_name>Amargosa vole</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1639</id>
#     <scientific_name>Icaricia icarioides missionensis</scientific_name>
#     <common_name>Mission blue butterfly</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Insects</category>
#   </species>
#   <species>
#     <id>ES1640</id>
#     <scientific_name>Chelonia mydas</scientific_name>
#     <common_name>Green sea turtle</common_name>
#     <where_listed>East Pacific DPS</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Reptiles</category>
#   </species>
#   <species>
#     <id>ES1641</id>
#     <scientific_name>Eumops floridanus</scientific_name>
#     <common_name>Florida bonneted bat</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Mammals</category>
#   </species>
#   <species>
#     <id>ES1642</id>
#     <scientific_name>Quadrula fragosa</scientific_name>
#     <common_name>Winged Mapleleaf</common_name>
#     <where_listed>Wherever found, except where listed as an experimental population</where_listed>
#     <region_name>Midwest</region_name>
#     <region>3</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Clams</category>
#   </species>
#   <species>
#     <id>ES1643</id>
#     <scientific_name>Notropis simus pecosensis</scientific_name>
#     <common_name>Pecos bluntnose shiner</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Fishes</category>
#   </species>
#   <species>
#     <id>ES1644</id>
#     <scientific_name>Megapodius laperouse</scientific_name>
#     <common_name>Micronesian megapode</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Birds</category>
#   </species>
#   <species>
#     <id>ES1645</id>
#     <scientific_name>Heterelmis comalensis</scientific_name>
#     <common_name>Comal Springs riffle beetle</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Insects</category>
#   </species>
#   <species>
#     <id>ES1646</id>
#     <scientific_name>Texella cokendolpheri</scientific_name>
#     <common_name>Cokendolpher Cave Harvestman</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Arachnids</category>
#   </species>
#   <species>
#     <id>ES1647</id>
#     <scientific_name>Ptychocheilus lucius</scientific_name>
#     <common_name>Colorado pikeminnow (=squawfish)</common_name>
#     <where_listed>Wherever found, except where listed as an experimental population</where_listed>
#     <region_name>Mountain-Prairie</region_name>
#     <region>6</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Fishes</category>
#   </species>
#   <species>
#     <id>ES1648</id>
#     <scientific_name>Cyprinella caerulea</scientific_name>
#     <common_name>Blue shiner</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Fishes</category>
#   </species>
#   <species>
#     <id>ES1650</id>
#     <scientific_name>Villosa fabalis</scientific_name>
#     <common_name>Rayed Bean</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Midwest</region_name>
#     <region>3</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Clams</category>
#   </species>
#   <species>
#     <id>ES1651</id>
#     <scientific_name>Drosophila obatai</scientific_name>
#     <common_name>Hawaiian picture-wing fly</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Insects</category>
#   </species>
#   <species>
#     <id>ES1652</id>
#     <scientific_name>Epioblasma obliquata obliquata</scientific_name>
#     <common_name>Purple Cat's paw (=Purple Cat's paw pearlymussel)</common_name>
#     <where_listed>Wherever found; Except where listed as Experimental Populations</where_listed>
#     <region_name>Midwest</region_name>
#     <region>3</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Clams</category>
#   </species>
#   <species>
#     <id>ES1653</id>
#     <scientific_name>Rostrhamus sociabilis plumbeus</scientific_name>
#     <common_name>Everglade snail kite</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southeast</region_name>
#     <region>4</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Birds</category>
#   </species>
#   <species>
#     <id>ES1654</id>
#     <scientific_name>Hemignathus affinis</scientific_name>
#     <common_name>Maui nukupuu</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Birds</category>
#   </species>
#   <species>
#     <id>ES1655</id>
#     <scientific_name>Thermosphaeroma thermophilus</scientific_name>
#     <common_name>Socorro isopod</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Southwest</region_name>
#     <region>2</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Crustaceans</category>
#   </species>
#   <species>
#     <id>ES1656</id>
#     <scientific_name>Strix occidentalis caurina</scientific_name>
#     <common_name>Northern spotted owl</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific</region_name>
#     <region>1</region>
#     <esa_listing_status>Threatened</esa_listing_status>
#     <category>Birds</category>
#   </species>
#   <species>
#     <id>ES1657</id>
#     <scientific_name>Sterna antillarum browni</scientific_name>
#     <common_name>California least tern</common_name>
#     <where_listed>Wherever found</where_listed>
#     <region_name>Pacific Southwest</region_name>
#     <region>8</region>
#     <esa_listing_status>Endangered</esa_listing_status>
#     <category>Birds</category>
#   </species>
# </animals_and_plants>

# %%
# define function to collaps duplicates in list 
#lambda df: lang_pred_with_pub(df)
def collaps_to_set(dataFrame):
    
    # build in check if group contains more thans one entry
    if len(dataFrame) <= 1:
        return dataFrame
    
    # collaps where_listed
    # should return a list of the series
    where_listed_list = list(dataFrame['where_listed'].unique())
    # set all rows to the list name
    dataFrame['where_listed'] = '|'.join(where_listed_list)
    
    
    # collaps region
    # should return a list of the series
    region_list = list(dataFrame['region'].unique())
    # convert integers in list to strings
    region_list = [str(i) for i in range(len(region_list))]
    # set all rows to the list name
    dataFrame['region'] = '|'.join(region_list)
    
    
    # collaps region_name
    # should return a list of the series
    region_name_list = list(dataFrame['region_name'].unique())
    # set all rows to the list name
    dataFrame['region_name'] = '|'.join(region_name_list)
    
    
    # collaps esa_listing_status
    # should return a list of the series
    esa_listing_status_list = list(dataFrame['esa_listing_status'].unique())
    # set all rows to the list name
    dataFrame['esa_listing_status'] = '|'.join(esa_listing_status_list)
    
    # return only one row from the data frame
    return_row = dataFrame.iloc[[0],:]
    
    return return_row

# %%
df = df.groupby('scientific_name').apply(lambda x: collaps_to_set(x)).reset_index(drop=True)

# %%
df[df['scientific_name'] == 'Chelonia mydas']
# Out:
#          id scientific_name       common_name  \
# 235  ES1005  Chelonia mydas  Green sea turtle
#
#                                           where_listed  \
# 235  North Atlantic DPS|South Atlantic DPS|Central ...
#
#                              region_name region     esa_listing_status  \
# 235  Southeast|Pacific|Pacific Southwest  0|1|2  Threatened|Endangered
#
#      category
# 235  Reptiles

# %%
# save DataFrame to .csv
df.to_csv('../Data/species-listings-by-tax-group-report_animals_and_plants_optimized.csv', index = False)

# %%
def convert_to_xml_species(row, output_file):
    
    # add species opening tag to xml string
    xml_species = ['<Species>']
    
    # get ID from the row
    ident = row['id']
    #create ID string with attribute value by substituting {} with ident
    xml_species.append('  <ID>{}</ID>'.format(ident))
    
    #create Provenance string with attribute value by substituting {} with ident
    xml_species.append('  <Provenance>{}</Provenance>'.format('FWS-EndangeredSpecies'))

    
    # get scientific name from the row
    scientific_name = row['scientific_name']
    #create scientific_name string with attribute value by substituting {} with scientific_name
    xml_species.append('  <Scientific_Name>{}</Scientific_Name>'.format(scientific_name))
    
    # get common name from the row
    common_name = row['common_name']
    #create common_name string with attribute value by substituting {} with common_name
    xml_species.append('  <Common_Names>')
    xml_species.append('    <Common_Name>{}</Common_Name>'.format(common_name))
    xml_species.append('  </Common_Names>')

    
    # cast list string back to a list object
    # and check if attribute is of type string, if not cast to string
    if not isinstance(row['where_listed'], str):
        where_listed_list = str(row['where_listed']).split('|')
    else:
        where_listed_list = row['where_listed'].split('|')
    ## here the conversion to XML of the list attributes
    xml_species.append('  <Where_Listeds>')
    for i in range(len(where_listed_list)):
        # get where_listed from the list element
        where_listed = where_listed_list[i]
        #create common_name string with attribute value by substituting {} with common_name
        xml_species.append('    <Where_Listed>{}</Where_Listed>'.format(where_listed))
    xml_species.append('  </Where_Listeds>')
        
    # cast list string back to a list object
    # and check if attribute is of type string, if not cast to string
    if not isinstance(row['region'], str):
        region_list = str(row['region']).split('|')
    else:
        region_list = row['region'].split('|')
    ## here the conversion to XML of the list attributes
    xml_species.append('  <Regions>')
    for i in range(len(region_list)):
        # get where_listed from the list element
        region = region_list[i]
        #create common_name string with attribute value by substituting {} with region
        xml_species.append('    <Region>{}</Region>'.format(region))
    xml_species.append('  </Regions>')
      
    # cast list string back to a list object
    region_name_list = row['region_name'].split('|')
    ## here the conversion to XML of the list attributes
    xml_species.append('  <Region_Names>')
    for i in range(len(region_name_list)):
        # get where_listed from the list element
        region_name = region_name_list[i]
        #create common_name string with attribute value by substituting {} with region_name
        xml_species.append('    <Region_Name>{}</Region_Name>'.format(region_name))
    xml_species.append('  </Region_Names>')
   
    # cast list string back to a list object
    esa_listing_status_list = row['esa_listing_status'].split('|')
    ## here the conversion to XML of the list attributes
    xml_species.append('  <Esa_Listing_Statuses>')
    for i in range(len(esa_listing_status_list)):
        # get where_listed from the list element
        esa_listing_status = esa_listing_status_list[i]
        #create common_name string with attribute value by substituting {} with region_name
        xml_species.append('    <Esa_Listing_Status>{}</Esa_Listing_Status>'.format(esa_listing_status))
    xml_species.append('  </Esa_Listing_Statuses>')
    
    # get category from the row
    category = row['category']
    #create category string with attribute value by substituting {} with category
    xml_species.append('  <Categories>')
    xml_species.append('    <Category>{}</Category>'.format(category))
    xml_species.append('  </Categories>')

    
    # add species closing tag to xml string
    xml_species.append('</Species>')
  
    species_element = '\n'.join(xml_species)
    #print(species_element)
    
    # open output file
    f = open(output_file, "a")
    # write to output file
    f.write(species_element + "\n")
    
    return row

# %%
#df.apply(lambda row: convert_to_xml_species(row, output_file), axis =1)

# %%
# define the destination file
species_xml = "../xml/endangered_species.xml"

# open fiele with writing, thus the current file is overwritten
f = open(species_xml, "w")
# write the start of the XML document
f.write("<?xml version='1.0' encoding='utf-8'?>\n<Animals_and_Plants>\n")
f.close()

# run the function and give it the destination file as attribute
# it will append any species elements to the file, without overwriting
# the existing information
df.apply(lambda row: convert_to_xml_species(row, species_xml), axis =1)

# append the closing tag of the XML to the document
f = open(species_xml, "a")
f.write("</Animals_and_Plants>")
f.close()
